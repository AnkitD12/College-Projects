# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d290add-cedf-4bea-9369-7fe735844779" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d290add-cedf-4bea-9369-7fe735844779">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
Data=pd.read_csv('kc_house_data - kc_house_data.csv')

# %%
Data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#Python Code to drop NaN values
Data=Data.dropna()

# %%
Data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
#Python Code to remove duplicate values
Data=Data.drop_duplicates()

# %%
Data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
#Python code to remove outliers
#We find outliers by box plot of each numerical variable
#Import matplotlib
import matplotlib.pyplot as plt
plt.boxplot(Data["price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f65bcd7ee60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f65bcea76a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f65bce947f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f65bcea62c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f65bcea61d0>],
#  'means': []}

# %%
#We will store outlier rows in list
OutlierList=[]

# %%
Data["price"].shape[0]
# Out:
# 21613

# %%
Data=Data.reset_index()

# %%
OutlierList=[]
for i in range(Data["price"].shape[0]):
  if Data["price"][i]>=5000000:
    OutlierList.append(i)  #Whichever value is >5000000, we will append its index to OutlierList
print(OutlierList)
# Out:
# [1164, 1315, 1448, 3914, 4411, 7252, 9254]

# %%
#Python code to drop or delete particular row
Data=Data.drop(OutlierList)

# %%
plt.boxplot(Data["price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f65bcfd61a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f65bcfd7550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f65bcfd5c90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f65bcfd7700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f65bcfd6350>],
#  'means': []}

# %%
Data=Data.reset_index()

# %%
Data.head()
# Out:
#    level_0  index          id             date     price  bedrooms  bathrooms  \
# 0        0      0  7129300520  20141013T000000  221900.0         3       1.00
# 1        1      1  6414100192  20141209T000000  538000.0         3       2.25
# 2        2      2  5631500400  20150225T000000  180000.0         2       1.00
# 3        3      3  2487200875  20141209T000000  604000.0         4       3.00
# 4        4      4  1954400510  20150218T000000  510000.0         3       2.00
#
#    sqft_living  sqft_lot  floors  ...  grade  sqft_above  sqft_basement  \
# 0         1180      5650     1.0  ...      7        1180              0
# 1         2570      7242     2.0  ...      7        2170            400
# 2          770     10000     1.0  ...      6         770              0
# 3         1960      5000     1.0  ...      7        1050            910
# 4         1680      8080     1.0  ...      8        1680              0
#
# ...

# %%
X= Data["bedrooms"]
Y=Data["price"]
plt.scatter(X,Y)
plt.title("Scatter plot for Price Vs Number of bedrooms")
plt.xlabel("bedrooms")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
Data.describe()
# Out:
#             level_0         index            id         price      bedrooms  \
# count  21606.000000  21606.000000  2.160600e+04  2.160600e+04  21606.000000
# mean   10808.169953  10808.169953  4.579658e+09  5.383679e+05      3.370175
# std     6238.902945   6238.902945  2.876254e+09  3.528909e+05      0.929432
# min        0.000000      0.000000  1.000102e+06  7.500000e+04      0.000000
# 25%     5406.250000   5406.250000  2.123049e+09  3.215000e+05      3.000000
# 50%    10809.500000  10809.500000  3.904926e+09  4.500000e+05      3.000000
# 75%    16210.750000  16210.750000  7.308600e+09  6.450000e+05      4.000000
# max    21612.000000  21612.000000  9.900000e+09  4.670000e+06     33.000000
#
#           bathrooms   sqft_living      sqft_lot        floors    waterfront  \
# count  21606.000000  21606.000000  2.160600e+04  21606.000000  21606.000000
# mean       2.113487   2077.584606  1.510142e+04      1.494122      0.007405
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
SLR=LinearRegression()

# %%
import numpy as np

# %%
X_train=np.array(X_train).reshape(-1,1)
X_train
# Out:
# array([[4],
#        [4],
#        [6],
#        ...,
#        [4],
#        [3],
#        [4]])

# %%
SLR.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
b0=SLR.intercept_
b0
# Out:
# 127921.15902609524

# %%
b1=SLR.coef_
b1
# Out:
# array([121954.36885695])

# %%
Y=Data["price"]

# %%
X=Data["sqft_living15"]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,Y)
plt.title("ScatterPlot For Price Vs Sqft Living Area")
plt.xlabel("Sqft Area")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')
